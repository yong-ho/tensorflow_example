# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5242, 3082, 12, 6, 195, 2, 3137, 46, 59, 156]

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'a', 'originated', 'term', 'as', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['originated', 'anarchism', 'term', 'a', 'term', 'as', 'of', 'originated']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.687043
# Nearest to used: timurid, fabrication, commoners, venerated, hen, le, voucher, control,
# Nearest to six: abimelech, lax, successor, curse, dissociatives, contradiction, reprisals, demoralized,
# Nearest to during: domitian, menahem, mujahideen, flagging, chem, sierra, displaying, lycanthropy,
# Nearest to it: nowadays, amplifiers, gradual, scroll, sur, tam, loanwords, stapleton,
# Nearest to th: carrion, doomed, conventions, delian, henslow, slugging, perigee, dvds,
# Nearest to about: hanoverian, chariot, atrial, alienation, clothing, gauze, mutilated, parke,
# Nearest to its: convex, titus, tuareg, seasonal, sculptors, anticommunist, organizations, vows,
# Nearest to he: kosi, cork, lips, shusui, decode, idiot, zur, winningest,
# Nearest to other: cobain, xiang, alde, corroborate, audition, spl, reacted, rampant,
# Nearest to would: misunderstanding, runner, specials, multiplications, worldcon, vein, administratives, masculinity,
# Nearest to and: guise, approx, brethren, replies, skilled, snapper, extrapolated, lipstick,
# Nearest to had: lobster, jobs, mitochondrion, philips, voce, tentatively, centronics, paraphrased,
# Nearest to if: anna, prophecy, stenella, subsequently, townes, jaffa, designates, banco,
# Nearest to united: fernand, untimely, mingus, pcd, scars, waterways, farthing, cinco,
# Nearest to not: derek, freer, sherwood, wannsee, crater, heijenoort, slippage, dull,
# Nearest to on: booths, hw, meriwether, theologian, bev, cosmic, degenerate, rivets,
# Average loss at step 2000: 4.362019
# Average loss at step 4000: 3.867558
# Average loss at step 6000: 3.792340
# Average loss at step 8000: 3.686382
# Average loss at step 10000: 3.618674
# Nearest to used: said, graphing, found, venerated, known, monophysitism, commoners, thicknesses,
# Nearest to six: seven, eight, five, four, three, nine, zero, two,
# Nearest to during: in, at, domitian, lonergan, mujahideen, flagging, administrators, tremblay,
# Nearest to it: he, this, there, they, not, hum, mommu, that,
# Nearest to th: three, four, five, dvds, pleasurable, delian, seven, reported,
# Nearest to about: paperwork, clothing, jurist, alienation, bale, atrial, publically, wiener,
# Nearest to its: the, their, his, this, titus, socks, semiotics, planting,
# Nearest to he: it, they, never, she, who, kosi, brill, cegep,
# Nearest to other: gregorio, bad, cobain, cask, lictors, corroborate, amputation, pitching,
# Nearest to would: may, should, symbolizes, web, riverfront, protestants, mycenae, made,
# Nearest to and: or, enamel, d, who, but, lump, burgnich, miriam,
# Nearest to had: has, have, was, shipboard, excitotoxins, phenomenology, notebooks, were,
# Nearest to if: prophecy, video, designates, ace, soul, greenfacts, stenella, ungrammatical,
# Nearest to united: mingus, newsmagazine, great, waterways, scars, hurry, myr, fernand,
# Nearest to not: it, preterist, shabazz, also, they, arbuthnot, bugtraq, still,
# Nearest to on: in, at, between, deluded, sans, upon, valerian, meriwether,
# Average loss at step 12000: 3.605606
# Average loss at step 14000: 3.575466
# Average loss at step 16000: 3.411206
# Average loss at step 18000: 3.457051
# Average loss at step 20000: 3.539026
# Nearest to used: found, known, graphing, said, commoners, dad, chrome, thicknesses,
# Nearest to six: eight, seven, four, five, three, nine, two, zero,
# Nearest to during: at, in, after, lonergan, administrators, domitian, nascent, guilford,
# Nearest to it: he, this, there, they, not, which, headphones, she,
# Nearest to th: pleasurable, madagascar, gilberts, dvds, boziz, upheaval, conventions, reported,
# Nearest to about: paperwork, alienation, jurist, bale, clothing, reptilian, hirschfeld, silence,
# Nearest to its: their, his, the, socks, some, kung, weeping, francophones,
# Nearest to he: it, she, they, who, there, never, cegep, postage,
# Nearest to other: many, some, bad, instill, raul, these, are, pitching,
# Nearest to would: may, can, could, should, will, to, must, shall,
# Nearest to and: or, but, from, in, absolution, enamel, american, while,
# Nearest to had: has, have, was, were, been, shipboard, having, petropavlovsk,
# Nearest to if: when, subsequently, appears, silverberg, designates, soul, without, prophecy,
# Nearest to united: newsmagazine, great, gregorian, mingus, scars, waterways, serfdom, sassanid,
# Nearest to not: it, shabazz, they, preterist, also, still, arbuthnot, usually,
# Nearest to on: in, at, upon, webelements, valerian, deluded, meriwether, between,
# Average loss at step 22000: 3.508034
# Average loss at step 24000: 3.489566
# Average loss at step 26000: 3.478727
# Average loss at step 28000: 3.480823
# Average loss at step 30000: 3.504161
# Nearest to used: known, found, graphing, said, considered, unknowable, waived, chrome,
# Nearest to six: four, seven, eight, five, nine, three, two, zero,
# Nearest to during: after, in, at, under, when, lonergan, by, for,
# Nearest to it: he, this, there, she, they, which, not, often,
# Nearest to th: bc, one, eight, pleasurable, boziz, madagascar, four, seven,
# Nearest to about: paperwork, jurist, alienation, downed, reptilian, on, bale, voyager,
# Nearest to its: their, the, his, some, kung, her, socks, engendered,
# Nearest to he: it, she, they, who, there, never, postage, positioned,
# Nearest to other: bad, some, many, these, universality, robotics, those, raul,
# Nearest to would: could, may, can, will, should, must, to, shall,
# Nearest to and: or, but, who, amused, cryptography, conqueror, of, however,
# Nearest to had: has, have, was, were, since, having, tur, became,
# Nearest to if: when, subsequently, where, although, silverberg, adolescence, without, combative,
# Nearest to united: gregorian, newsmagazine, fernand, great, scars, mingus, autograph, sassanid,
# Nearest to not: they, it, shabazz, still, generally, preterist, also, conquer,
# Nearest to on: upon, in, at, webelements, under, between, through, meriwether,
# Average loss at step 32000: 3.503284
# Average loss at step 34000: 3.493886
# Average loss at step 36000: 3.463716
# Average loss at step 38000: 3.305258
# Average loss at step 40000: 3.431083
# Nearest to used: found, known, considered, referred, seen, chrome, graphing, unknowable,
# Nearest to six: four, seven, eight, five, nine, three, two, zero,
# Nearest to during: after, at, in, against, until, under, when, ebony,
# Nearest to it: he, there, this, she, they, rawlinson, which, sometimes,
# Nearest to th: bc, pleasurable, boziz, madagascar, muons, rd, nd, eight,
# Nearest to about: on, alienation, paperwork, reptilian, watergate, renn, immutable, jurist,
# Nearest to its: their, his, the, her, kung, garlic, socks, idriss,
# Nearest to he: she, it, they, there, who, never, postage, assemblers,
# Nearest to other: bad, various, instill, those, different, rowe, lubricant, cousteau,
# Nearest to would: could, will, may, can, should, must, might, did,
# Nearest to and: or, but, workable, rau, with, like, enamel, wuxia,
# Nearest to had: has, have, was, were, been, having, became, zhaozhou,
# Nearest to if: when, where, is, designates, trichomes, subsequently, must, screech,
# Nearest to united: gregorian, fernand, sassanid, scars, newsmagazine, thenceforth, serfdom, autograph,
# Nearest to not: still, generally, shabazz, they, often, nationalists, hydroxybutyrate, conquer,
# Nearest to on: upon, about, in, at, from, between, meriwether, deluded,
# Average loss at step 42000: 3.429572
# Average loss at step 44000: 3.455704
# Average loss at step 46000: 3.452470
# Average loss at step 48000: 3.355415
# Average loss at step 50000: 3.384202
# Nearest to used: known, found, referred, considered, seen, written, given, available,
# Nearest to six: eight, seven, four, nine, five, three, two, zero,
# Nearest to during: after, in, under, when, at, until, before, within,
# Nearest to it: he, there, this, she, they, rawlinson, still, also,
# Nearest to th: bc, one, pleasurable, muons, boziz, nd, eight, rd,
# Nearest to about: vision, alienation, on, idyllic, voyager, watergate, reptilian, over,
# Nearest to its: their, his, the, her, engendered, formaldehyde, kung, ewes,
# Nearest to he: she, it, they, who, there, this, postage, laconic,
# Nearest to other: various, different, many, bad, those, linguistic, instill, ewell,
# Nearest to would: could, will, can, may, should, might, must, did,
# Nearest to and: or, but, including, however, of, while, djibouti, codified,
# Nearest to had: has, have, was, were, having, been, suggested, zhaozhou,
# Nearest to if: when, where, although, designates, though, trichomes, however, did,
# Nearest to united: sassanid, gregorian, newsmagazine, fernand, scars, thenceforth, serfdom, majors,
# Nearest to not: still, shabazz, never, hydroxybutyrate, generally, now, they, alanine,
# Nearest to on: upon, in, at, from, about, meriwether, collation, through,
# Average loss at step 52000: 3.435883
# Average loss at step 54000: 3.428691
# Average loss at step 56000: 3.439899
# Average loss at step 58000: 3.395969
# Average loss at step 60000: 3.391774
# Nearest to used: known, found, considered, written, seen, referred, required, designed,
# Nearest to six: four, eight, five, seven, nine, three, zero, two,
# Nearest to during: after, in, before, following, when, until, although, under,
# Nearest to it: he, there, this, she, which, rawlinson, generally, that,
# Nearest to th: bc, nd, seven, six, pleasurable, muons, rd, boziz,
# Nearest to about: alienation, vision, galatia, over, on, that, chariot, uppsala,
# Nearest to its: their, his, the, her, kung, engendered, redirection, formaldehyde,
# Nearest to he: she, it, they, there, who, eventually, we, rawlinson,
# Nearest to other: various, different, those, many, bad, instill, several, robotics,
# Nearest to would: could, will, can, may, should, might, must, does,
# Nearest to and: or, but, unmik, in, including, than, inciting, synthesis,
# Nearest to had: has, have, was, were, having, became, dxm, suggested,
# Nearest to if: when, where, although, though, adolescence, because, could, since,
# Nearest to united: sassanid, newsmagazine, thenceforth, gregorian, fernand, majors, scars, serfdom,
# Nearest to not: still, never, now, shabazz, usually, generally, you, they,
# Nearest to on: upon, through, in, meriwether, about, against, squatters, webelements,
# Average loss at step 62000: 3.247045
# Average loss at step 64000: 3.253460
# Average loss at step 66000: 3.404132
# Average loss at step 68000: 3.398521
# Average loss at step 70000: 3.359175
# Nearest to used: known, found, written, seen, considered, responsible, designed, available,
# Nearest to six: eight, seven, four, five, nine, three, two, zero,
# Nearest to during: after, before, until, in, since, following, under, throughout,
# Nearest to it: he, she, there, this, they, rawlinson, still, which,
# Nearest to th: bc, nd, pleasurable, muons, boziz, third, rd, six,
# Nearest to about: over, alienation, vision, viewer, idyllic, reptilian, that, on,
# Nearest to its: their, his, her, the, weeping, kung, careers, any,
# Nearest to he: she, it, they, there, eventually, never, finally, eraser,
# Nearest to other: various, different, madhu, referent, those, many, ewell, several,
# Nearest to would: will, could, can, may, might, should, must, does,
# Nearest to and: or, but, including, while, like, using, which, however,
# Nearest to had: have, has, was, were, having, cimeti, been, crystallized,
# Nearest to if: when, where, although, though, however, could, without, adolescence,
# Nearest to united: sassanid, thenceforth, newsmagazine, rabies, serfdom, fernand, gregorian, majors,
# Nearest to not: never, now, still, generally, usually, actually, mostly, always,
# Nearest to on: upon, through, in, meriwether, within, impatience, at, about,
# Average loss at step 72000: 3.375868
# Average loss at step 74000: 3.347589
# Average loss at step 76000: 3.317577
# Average loss at step 78000: 3.353759
# Average loss at step 80000: 3.380899
# Nearest to used: known, found, referred, written, responsible, considered, seen, available,
# Nearest to six: seven, five, four, eight, three, nine, two, zero,
# Nearest to during: after, in, before, when, until, under, despite, through,
# Nearest to it: he, she, there, this, they, still, publically, we,
# Nearest to th: bc, nd, rd, third, muons, pleasurable, five, boziz,
# Nearest to about: over, vision, alienation, galatia, ovid, watergate, codata, plug,
# Nearest to its: their, his, her, the, ankobra, idriss, theaters, our,
# Nearest to he: she, it, they, there, never, who, we, but,
# Nearest to other: various, many, referent, bram, those, different, linguistic, others,
# Nearest to would: will, could, can, may, might, should, must, shall,
# Nearest to and: or, but, including, than, while, cetaceans, although, passports,
# Nearest to had: have, has, was, having, were, dxm, became, been,
# Nearest to if: when, though, although, can, where, without, did, before,
# Nearest to united: sassanid, newsmagazine, thenceforth, fernand, majors, rabies, same, flickering,
# Nearest to not: still, now, never, actually, generally, usually, always, normally,
# Nearest to on: upon, through, in, webelements, outstripped, stoppage, valerian, during,
# Average loss at step 82000: 3.407879
# Average loss at step 84000: 3.408217
# Average loss at step 86000: 3.388262
# Average loss at step 88000: 3.354860
# Average loss at step 90000: 3.361968
# Nearest to used: known, referred, designed, considered, found, seen, responsible, written,
# Nearest to six: seven, eight, five, four, nine, three, two, zero,
# Nearest to during: after, before, in, until, when, while, within, although,
# Nearest to it: he, she, there, this, they, itself, actually, which,
# Nearest to th: bc, third, nd, rd, second, pleasurable, seven, st,
# Nearest to about: vision, over, galatia, alienation, shorty, watergate, ovid, reptilian,
# Nearest to its: their, his, her, the, our, redirection, your, careers,
# Nearest to he: she, they, it, there, who, but, we, originally,
# Nearest to other: various, referent, different, including, bram, ramadan, marianne, robotics,
# Nearest to would: could, will, may, can, might, should, must, did,
# Nearest to and: or, but, including, while, vytautas, in, however, wto,
# Nearest to had: has, have, was, having, were, dxm, continued, previously,
# Nearest to if: when, where, though, although, since, did, can, however,
# Nearest to united: sassanid, serfdom, newsmagazine, majors, thenceforth, rabies, flickering, fernand,
# Nearest to not: still, never, actually, now, generally, almost, it, normally,
# Nearest to on: upon, through, under, webelements, in, sans, at, diuretic,
# Average loss at step 92000: 3.401943
# Average loss at step 94000: 3.252401
# Average loss at step 96000: 3.359470
# Average loss at step 98000: 3.244012
# Average loss at step 100000: 3.361664
# Nearest to used: referred, designed, known, considered, found, seen, responsible, applied,
# Nearest to six: four, seven, eight, five, nine, three, two, zero,
# Nearest to during: after, in, before, following, when, until, throughout, although,
# Nearest to it: he, she, this, there, they, rawlinson, nothing, still,
# Nearest to th: bc, nd, third, rd, second, viet, next, one,
# Nearest to about: vision, idyllic, alienation, watergate, on, galatia, immutable, coppersmith,
# Nearest to its: their, his, her, the, our, ankobra, maronites, engendered,
# Nearest to he: she, it, they, there, who, we, never, soon,
# Nearest to other: various, referent, others, different, bram, universities, newer, dirichlet,
# Nearest to would: could, will, may, can, might, should, must, did,
# Nearest to and: or, but, while, although, when, however, including, who,
# Nearest to had: has, have, was, having, were, chose, would, is,
# Nearest to if: when, though, where, although, since, while, did, because,
# Nearest to united: sassanid, same, majors, rabies, newsmagazine, serfdom, gregorian, flickering,
# Nearest to not: never, still, generally, now, almost, actually, they, always,
# Nearest to on: upon, in, within, through, at, under, acker, against,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
